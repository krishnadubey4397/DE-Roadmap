# %%
data = [ {"name": "Krishna", "age": 22}, {"name": "Aman", "age": 19},{"name": "zeeshan", "age": 14}]

data.sort(key= lambda x: x['age'])
data
# Out:
# [{'name': 'zeeshan', 'age': 14},
#  {'name': 'Aman', 'age': 19},
#  {'name': 'Krishna', 'age': 22}]
